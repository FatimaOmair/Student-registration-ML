# %% [markdown]
# # Fatima Omair  202010325

# %% [markdown]
# <h3>Open University Learning Analytics<h3>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler, LabelEncoder
from scipy.stats import mode
import matplotlib.pyplot as plt

# %% [markdown]
# <h3>First file (studentRegistration.csv)<h3>
# <h5>Contains information about the time when the student registered for the module presentation. For students who unregistered, the date of un-registration is also recorded. It consists of 32,593 rows.</h5>

# %% [markdown]
# <h2>1---Loading the dataset and examining its structure.</h2>

# %%
# read csv file
firsttFile_reg = pd.read_csv("C:\\Users\\DELL\\Desktop\ML\\studentRegistration.csv")

# %%
#computes summary statistics of the numerical columns in the DataFrame.
firsttFile_reg.describe()
# Out:
#          id_student  date_registration  date_unregistration
# count  3.259300e+04       32548.000000         10072.000000
# mean   7.066877e+05         -69.411300            49.757645
# std    5.491673e+05          49.260522            82.460890
# min    3.733000e+03        -322.000000          -365.000000
# 25%    5.085730e+05        -100.000000            -2.000000
# 50%    5.903100e+05         -57.000000            27.000000
# 75%    6.444530e+05         -29.000000           109.000000
# max    2.716795e+06         167.000000           444.000000

# %%
# display the first 15 rows
firsttFile_reg.head(15)
# Out:
#    code_module code_presentation  id_student  date_registration  \
# 0          AAA             2013J       11391             -159.0
# 1          AAA             2013J       28400              -53.0
# 2          AAA             2013J       30268              -92.0
# 3          AAA             2013J       31604              -52.0
# 4          AAA             2013J       32885             -176.0
# 5          AAA             2013J       38053             -110.0
# 6          AAA             2013J       45462              -67.0
# 7          AAA             2013J       45642              -29.0
# 8          AAA             2013J       52130              -33.0
# 9          AAA             2013J       53025             -179.0
# 10         AAA             2013J       57506             -103.0
# 11         AAA             2013J       58873              -47.0
# 12         AAA             2013J       59185              -59.0
# 13         AAA             2013J       62155              -68.0
# ...

# %%
# display the last 15 rows
firsttFile_reg.tail(15)
# Out:
#       code_module code_presentation  id_student  date_registration  \
# 32578         GGG             2014J     2357806             -128.0
# 32579         GGG             2014J     2373245              -53.0
# 32580         GGG             2014J     2378591             -113.0
# 32581         GGG             2014J     2456431              -70.0
# 32582         GGG             2014J     2475886              -31.0
# 32583         GGG             2014J     2508153              -59.0
# 32584         GGG             2014J     2533195              -45.0
# 32585         GGG             2014J     2606765              -64.0
# 32586         GGG             2014J     2608143              -45.0
# 32587         GGG             2014J     2620947              -23.0
# 32588         GGG             2014J     2640965               -4.0
# 32589         GGG             2014J     2645731              -23.0
# 32590         GGG             2014J     2648187             -129.0
# ...

# %%
# generate descriptive statistics of the data in a DataFrame. 
firsttFile_reg.describe()
# Out:
#          id_student  date_registration  date_unregistration
# count  3.259300e+04       32548.000000         10072.000000
# mean   7.066877e+05         -69.411300            49.757645
# std    5.491673e+05          49.260522            82.460890
# min    3.733000e+03        -322.000000          -365.000000
# 25%    5.085730e+05        -100.000000            -2.000000
# 50%    5.903100e+05         -57.000000            27.000000
# 75%    6.444530e+05         -29.000000           109.000000
# max    2.716795e+06         167.000000           444.000000

# %%
#provides a concise summary of the DataFrame
firsttFile_reg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32593 entries, 0 to 32592
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   code_module          32593 non-null  object
#  1   code_presentation    32593 non-null  object
#  2   id_student           32593 non-null  int64
#  3   date_registration    32548 non-null  float64
#  4   date_unregistration  10072 non-null  float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.2+ MB

# %%
# returns a tuple representing the dimensions of the DataFrame.
firsttFile_reg.shape
# Out:
# (32593, 5)

# %%
#show data type for colums
columnTypes = firsttFile_reg.dtypes

# %%
print(columnTypes)
# Out:
# code_module             object
# code_presentation       object
# id_student               int64
# date_registration      float64
# date_unregistration    float64
# dtype: object

# %%
#count the number of missing values (NaNs) in each column of the DataFrame.
firsttFile_reg.isnull().sum()
# Out:
# code_module                0
# code_presentation          0
# id_student                 0
# date_registration         45
# date_unregistration    22521
# dtype: int64

# %% [markdown]
# <h2>2--- Summarizing statistical properties of the dataset (mean, median, standard deviation, etc.).</h2>

# %%
#first numeric column 'id_student '
date_student = firsttFile_reg['date_registration']

# %%
MeanDateStudent = np.mean(date_student)

# %%
print(MeanDateStudent)
# Out:
# -69.4113002335013

# %%
STDDatestudent = np.std(date_student)

# %%
print(STDDatestudent)
# Out:
# 49.25976537266152

# %%
MedianDateStudent = np.median(date_student)

# %%
print(MedianDateStudent)
# Out:
# nan

# %%
#second numeric column 'date_unregistration'
date_unregistrationCol = firsttFile_reg['date_unregistration']

# %%
MeanDateUnReg = np.mean(date_unregistrationCol)

# %%
print(MeanDateUnReg)
# Out:
# 49.757644956314536

# %%
STDDateUnReg = np.std(date_unregistrationCol)

# %%
print(STDDateUnReg)
# Out:
# 82.45679628573502

# %%
MedianDateUnReg = np.median(date_unregistrationCol)

# %%
print(MedianDateUnReg)
# Out:
# nan

# %%
#represents the most frequently occurring value in each column.
modes1 =firsttFile_reg.mode()

# %%
print(modes1)
# Out:
#   code_module code_presentation  id_student  date_registration  \
# 0         BBB             2014J      584077              -22.0
#
#    date_unregistration
# 0                 12.0

# %% [markdown]
# <h2>3--- Visualizing the data using appropriate plots (scatter plots, histograms, etc.).</h2>

# %%
#A scatter plot is useful for visualizing the relationship between date_unregistration and date_registration
plt.scatter(firsttFile_reg['date_registration'], firsttFile_reg['date_unregistration'])
plt.xlabel('date_registration')
plt.ylabel('date_unregistration')
plt.title('Scatter Plot of date_unregistration vs date_unregistration')
plt.show()

# %%
#A histogram is useful for visualizing the distribution of a single variable.(date_unregistration)
plt.hist(firsttFile_reg['date_unregistration'], bins=10)
plt.xlabel('date_unregistration')
plt.ylabel('Frequency')
plt.title('Histogram of date_unregistration')
plt.show()

# %%
#A histogram is useful for visualizing the distribution of a single variable.(date_registration)
plt.hist(firsttFile_reg['date_registration'], bins=10)
plt.xlabel('date_registration')
plt.ylabel('Frequency')
plt.title('Histogram of date_registration')
plt.show()

# %%
#A bar plot is useful for comparing different categories.
firsttFile_reg['code_presentation'].value_counts().plot(kind='bar')
plt.xlabel('code_presentation ')
plt.ylabel('Count')
plt.title('Bar Plot of code_presentation ')
plt.show()

# %%
#A box plot is useful for visualizing the distribution of numerical data and detecting outliers.
plt.boxplot(firsttFile_reg['date_unregistration'].dropna())
plt.ylabel('date_unregistration')
plt.title('Box Plot of date_unregistration')
plt.show()

# %%
#This code snippet is designed to create visualizations for each column in a DataFrame . It iterates over each column, checks its data type, and then creates a specific type of plot based on that data type.

for column in firsttFile_reg.columns:
    # Check the data type of the column
    dtype = firsttFile_reg[column].dtype
    
    # If the column is numeric, create a histogram
    if pd.api.types.is_numeric_dtype(dtype):
        plt.hist(firsttFile_reg[column].dropna())
        plt.xlabel(column)
        plt.ylabel('Frequency')
        plt.title(f'Histogram of {column}')
        plt.show()
        
    # If the column is categorical or object type, create a bar plot
    elif pd.api.types.is_categorical_dtype(dtype) or pd.api.types.is_object_dtype(dtype):
        firsttFile_reg[column].value_counts().plot(kind='bar')
        plt.xlabel(column)
        plt.ylabel('Count')
        plt.title(f'Bar Plot of {column}')
        plt.show()
        
    # For other types, you can customize the visualization based on your data and requirements
    else:
        print(f'No visualization available for column "{column}" with dtype {dtype}')

# %%
#This code snippet iterates over each column in the DataFrame , checks its data type, and then creates either a scatter plot or a pie chart based on the data type of each column.

for column in firsttFile_reg.columns:
    # Check the data type of the column
    dtype = firsttFile_reg[column].dtype
    
    # If the column is numeric, create a scatter plot
    if pd.api.types.is_numeric_dtype(dtype):
        plt.scatter(firsttFile_reg[column].index, firsttFile_reg[column], color='skyblue')  # Change colors
        plt.xlabel('Index')
        plt.ylabel(column)
        plt.title(f'Scatter Plot of {column}')
        plt.show()
        
    # If the column is categorical or object type, create a pie plot
    elif pd.api.types.is_categorical_dtype(dtype) or pd.api.types.is_object_dtype(dtype):
        firsttFile_reg[column].value_counts().plot(kind='pie', colors=['salmon', 'skyblue', 'orange'])  # Change colors
        plt.ylabel('')
        plt.title(f'Pie Chart of {column}')
        plt.show()
        
    # For other types, you can customize the visualization based on your data and requirements
    else:
        print(f'No visualization available for column "{column}" with dtype {dtype}')

# %%
#The code visualizes each column in the DataFrame . If a column contains categorical data, 
#it creates a count plot using Seaborn's countplot(). For numerical columns, 
#it creates a histogram using Seaborn's histplot(). The plots are displayed one by one using plt.show().

for column in firsttFile_reg.columns:
    if firsttFile_reg[column].dtype == 'object':
        plt.figure(figsize=(8, 6))
        sns.countplot(data=firsttFile_reg, x=column)
        plt.xlabel(column)
        plt.ylabel('Count')
        plt.xticks(rotation=45) 
        plt.show()
    else:
        plt.figure(figsize=(8, 6))
        sns.histplot(firsttFile_reg[column], bins=20, kde=True, color='blue')
        plt.xlabel(column)
        plt.ylabel('Frequency')
        plt.show()

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# <h2> 1---Handling missing values.</h2>

# %%
#Fills missing values (NaNs) in the 'date_unregistration' column of the DataFrame  with the mean of the non-missing values in the same column.

firsttFile_reg['date_unregistration'].fillna(firsttFile_reg['date_unregistration'].mean(), inplace=True)

# %%
#Fills missing values (NaNs) in the 'date_registration' column of the DataFrame  with the mean of the non-missing values in the same column.

firsttFile_reg['date_registration'].fillna(firsttFile_reg['date_registration'].mean(), inplace=True)

# %%
#We notice there are no NaN value in date column now
firsttFile_reg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32593 entries, 0 to 32592
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   code_module          32593 non-null  object
#  1   code_presentation    32593 non-null  object
#  2   id_student           32593 non-null  int64
#  3   date_registration    32593 non-null  float64
#  4   date_unregistration  32593 non-null  float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.2+ MB

# %% [markdown]
# <h2>2---Normalizing or standardizing features.</h2>

# %%
# scale the 'date_registration' column  to a range between 0 and 1. ( normalization)
scaler = MinMaxScaler()
firsttFile_reg['date_registration'] = scaler.fit_transform(firsttFile_reg[['date_registration']])

# %%
# scale the 'date_unregistration' column  to a range between 0 and 1. 
firsttFile_reg['date_unregistration'] = scaler.fit_transform(firsttFile_reg[['date_unregistration']])

# %%
firsttFile_reg
# Out:
#       code_module code_presentation  id_student  date_registration  \
# 0             AAA             2013J       11391           0.333333
# 1             AAA             2013J       28400           0.550102
# 2             AAA             2013J       30268           0.470348
# 3             AAA             2013J       31604           0.552147
# 4             AAA             2013J       32885           0.298569
# ...           ...               ...         ...                ...
# 32588         GGG             2014J     2640965           0.650307
# 32589         GGG             2014J     2645731           0.611452
# 32590         GGG             2014J     2648187           0.394683
# 32591         GGG             2014J     2679821           0.558282
# 32592         GGG             2014J     2684003           0.601227
#
#        date_unregistration
# 0                 0.512679
# 1                 0.512679
# 2                 0.466007
# 3                 0.512679
# ...

# %% [markdown]
# <h2>3--- Encoding categorical variables (if any).</h2>

# %%
print(firsttFile_reg.columns)
# Out:
# Index(['code_module', 'code_presentation', 'id_student', 'date_registration',
#        'date_unregistration'],
#       dtype='object')

# %%
print(firsttFile_reg.head())
# Out:
#   code_module code_presentation  id_student  date_registration  \
# 0         AAA             2013J       11391           0.333333
# 1         AAA             2013J       28400           0.550102
# 2         AAA             2013J       30268           0.470348
# 3         AAA             2013J       31604           0.552147
# 4         AAA             2013J       32885           0.298569
#
#    date_unregistration
# 0             0.512679
# 1             0.512679
# 2             0.466007
# 3             0.512679
# 4             0.512679

# %% [markdown]
# <h3>Second file (Assessments.csv)<h3>
# <h5>This table contains information about assessments in module-presentations. Usually, every presentation has a number of assessments followed by the final exam.</h5>

# %% [markdown]
# <h2>1---Loading the dataset and examining its structure.</h2>

# %%
# read csv file
secondtFile_assessments = pd.read_csv("C:\\Users\\DELL\\Desktop\ML\\assessments.csv")

# %%
#computes summary statistics of the numerical columns in the DataFrame.
secondtFile_assessments.describe()
# Out:
#        id_assessment        date      weight
# count     206.000000  195.000000  206.000000
# mean    26473.975728  145.005128   20.873786
# std     10098.625521   76.001119   30.384224
# min      1752.000000   12.000000    0.000000
# 25%     15023.250000   71.000000    0.000000
# 50%     25364.500000  152.000000   12.500000
# 75%     34891.750000  222.000000   24.250000
# max     40088.000000  261.000000  100.000000

# %%
# display the first 15 rows
secondtFile_assessments.head(15)
# Out:
#    code_module code_presentation  id_assessment assessment_type   date  weight
# 0          AAA             2013J           1752             TMA   19.0    10.0
# 1          AAA             2013J           1753             TMA   54.0    20.0
# 2          AAA             2013J           1754             TMA  117.0    20.0
# 3          AAA             2013J           1755             TMA  166.0    20.0
# 4          AAA             2013J           1756             TMA  215.0    30.0
# 5          AAA             2013J           1757            Exam    NaN   100.0
# 6          AAA             2014J           1758             TMA   19.0    10.0
# 7          AAA             2014J           1759             TMA   54.0    20.0
# 8          AAA             2014J           1760             TMA  117.0    20.0
# 9          AAA             2014J           1761             TMA  166.0    20.0
# 10         AAA             2014J           1762             TMA  215.0    30.0
# ...

# %%
# display the last 15 rows
secondtFile_assessments.tail(15)
# Out:
#     code_module code_presentation  id_assessment assessment_type   date  \
# 191         GGG             2014B          37433             CMA  222.0
# 192         GGG             2014B          37425             TMA   61.0
# 193         GGG             2014B          37426             TMA  117.0
# 194         GGG             2014B          37427             TMA  166.0
# 195         GGG             2014B          37434            Exam  222.0
# 196         GGG             2014J          37438             CMA  229.0
# 197         GGG             2014J          37439             CMA  229.0
# 198         GGG             2014J          37440             CMA  229.0
# 199         GGG             2014J          37441             CMA  229.0
# 200         GGG             2014J          37442             CMA  229.0
# 201         GGG             2014J          37443             CMA  229.0
# 202         GGG             2014J          37435             TMA   61.0
# ...

# %%
#provides a concise summary of the DataFrame
secondtFile_assessments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   code_module        206 non-null    object
#  1   code_presentation  206 non-null    object
#  2   id_assessment      206 non-null    int64
#  3   assessment_type    206 non-null    object
#  4   date               195 non-null    float64
#  5   weight             206 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 9.8+ KB

# %%
# generate descriptive statistics of the data in a DataFrame. 
secondtFile_assessments.describe()
# Out:
#        id_assessment        date      weight
# count     206.000000  195.000000  206.000000
# mean    26473.975728  145.005128   20.873786
# std     10098.625521   76.001119   30.384224
# min      1752.000000   12.000000    0.000000
# 25%     15023.250000   71.000000    0.000000
# 50%     25364.500000  152.000000   12.500000
# 75%     34891.750000  222.000000   24.250000
# max     40088.000000  261.000000  100.000000

# %%
# returns a tuple representing the dimensions of the DataFrame.
secondtFile_assessments.shape
# Out:
# (206, 6)

# %%
#show data type for colums
colTypes = secondtFile_assessments.dtypes

# %%
print(colTypes)
# Out:
# code_module           object
# code_presentation     object
# id_assessment          int64
# assessment_type       object
# date                 float64
# weight               float64
# dtype: object

# %%
#count the number of missing values (NaNs) in each column of the DataFrame.
secondtFile_assessments.isnull().sum()
# Out:
# code_module           0
# code_presentation     0
# id_assessment         0
# assessment_type       0
# date                 11
# weight                0
# dtype: int64

# %% [markdown]
# <h2>2--- Summarizing statistical properties of the dataset (mean, median, standard deviation, etc.).</h2>

# %%
#first numeric column 'date'
dateCol = secondtFile_assessments['date']

# %%
MeanDate = np.mean(dateCol)

# %%
print(MeanDate)
# Out:
# 145.00512820512822

# %%
STDDate = np.std(dateCol)

# %%
print(STDDate)
# Out:
# 75.8059937712727

# %%
MedianDate = np.median(dateCol)

# %%
print(MedianDate)
# Out:
# nan

# %%
#second numeric column 'weight'
weigthCol = secondtFile_assessments['weight']

# %%
MeanWeight = np.mean(weigthCol)

# %%
print(MeanWeight)
# Out:
# 20.87378640776699

# %%
STDWeight = np.std(weigthCol)

# %%
print(STDWeight)
# Out:
# 30.31038612459988

# %%
MedianWeight = np.median(weigthCol)

# %%
print(MedianWeight)
# Out:
# 12.5

# %%
#represents the most frequently occurring value in each column.
modes =secondtFile_assessments.mode()

# %%
print(modes)
# Out:
#     code_module code_presentation  id_assessment assessment_type   date  \
# 0           FFF             2014B           1752             TMA  222.0
# 1           NaN             2014J           1753             NaN    NaN
# 2           NaN               NaN           1754             NaN    NaN
# 3           NaN               NaN           1755             NaN    NaN
# 4           NaN               NaN           1756             NaN    NaN
# ..          ...               ...            ...             ...    ...
# 201         NaN               NaN          37442             NaN    NaN
# 202         NaN               NaN          37443             NaN    NaN
# 203         NaN               NaN          37444             NaN    NaN
# 204         NaN               NaN          40087             NaN    NaN
# 205         NaN               NaN          40088             NaN    NaN
#
#      weight
# 0       0.0
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# ...

# %% [markdown]
# <h2>3--- Visualizing the data using appropriate plots (scatter plots, histograms, etc.).</h2>

# %%
#A scatter plot is useful for visualizing the relationship between weight and date
plt.scatter(secondtFile_assessments['date'], secondtFile_assessments['weight'])
plt.xlabel('Date')
plt.ylabel('Weight')
plt.title('Scatter Plot of Date vs Weight')
plt.show()

# %%
#A histogram is useful for visualizing the distribution of a single variable.(weight)
plt.hist(secondtFile_assessments['weight'], bins=10)
plt.xlabel('Weight')
plt.ylabel('Frequency')
plt.title('Histogram of Weight')
plt.show()

# %%
#A bar plot is useful for comparing different categories.
secondtFile_assessments['assessment_type'].value_counts().plot(kind='bar')
plt.xlabel('Assessment Type')
plt.ylabel('Count')
plt.title('Bar Plot of Assessment Types')
plt.show()

# %%
#A box plot is useful for visualizing the distribution of numerical data and detecting outliers.
plt.boxplot(secondtFile_assessments['weight'].dropna())
plt.ylabel('Weight')
plt.title('Box Plot of Weight')
plt.show()

# %%
#This code snippet is designed to create visualizations for each column in a DataFrame . It iterates over each column, checks its data type, and then creates a specific type of plot based on that data type.

for column in secondtFile_assessments.columns:
    # Check the data type of the column
    dtype = secondtFile_assessments[column].dtype
    
    # If the column is numeric, create a histogram
    if pd.api.types.is_numeric_dtype(dtype):
        plt.hist(secondtFile_assessments[column].dropna())
        plt.xlabel(column)
        plt.ylabel('Frequency')
        plt.title(f'Histogram of {column}')
        plt.show()
        
    # If the column is categorical or object type, create a bar plot
    elif pd.api.types.is_categorical_dtype(dtype) or pd.api.types.is_object_dtype(dtype):
        secondtFile_assessments[column].value_counts().plot(kind='bar')
        plt.xlabel(column)
        plt.ylabel('Count')
        plt.title(f'Bar Plot of {column}')
        plt.show()
        
    # For other types, you can customize the visualization based on your data and requirements
    else:
        print(f'No visualization available for column "{column}" with dtype {dtype}')

# %%
#This code snippet iterates over each column in the DataFrame , checks its data type, and then creates either a scatter plot or a pie chart based on the data type of each column.

for column in secondtFile_assessments.columns:
    # Check the data type of the column
    dtype = secondtFile_assessments[column].dtype
    
    # If the column is numeric, create a scatter plot
    if pd.api.types.is_numeric_dtype(dtype):
        plt.scatter(secondtFile_assessments[column].index, secondtFile_assessments[column], color='skyblue')  # Change colors
        plt.xlabel('Index')
        plt.ylabel(column)
        plt.title(f'Scatter Plot of {column}')
        plt.show()
        
    # If the column is categorical or object type, create a pie plot
    elif pd.api.types.is_categorical_dtype(dtype) or pd.api.types.is_object_dtype(dtype):
        secondtFile_assessments[column].value_counts().plot(kind='pie', colors=['salmon', 'skyblue', 'orange'])  # Change colors
        plt.ylabel('')
        plt.title(f'Pie Chart of {column}')
        plt.show()
        
    # For other types, you can customize the visualization based on your data and requirements
    else:
        print(f'No visualization available for column "{column}" with dtype {dtype}')

# %%
#The code visualizes each column in the DataFrame . If a column contains categorical data, 
#it creates a count plot using Seaborn's countplot(). For numerical columns, 
#it creates a histogram using Seaborn's histplot(). The plots are displayed one by one using plt.show().

for column in secondtFile_assessments.columns:
    if secondtFile_assessments[column].dtype == 'object':
        plt.figure(figsize=(8, 6))
        sns.countplot(data=secondtFile_assessments, x=column)
        plt.xlabel(column)
        plt.ylabel('Count')
        plt.xticks(rotation=45) 
        plt.show()
    else:
        plt.figure(figsize=(8, 6))
        sns.histplot(secondtFile_assessments[column], bins=20, kde=True, color='blue')
        plt.xlabel(column)
        plt.ylabel('Frequency')
        plt.show()

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# <h2> 1---Handling missing values.</h2>

# %%
#Fills missing values (NaNs) in the 'date' column of the DataFrame  with the mean of the non-missing values in the same column.

secondtFile_assessments['date'].fillna(secondtFile_assessments['date'].mean(), inplace=True)

# %%
#We notice there are no NaN value in date column now
secondtFile_assessments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   code_module        206 non-null    object
#  1   code_presentation  206 non-null    object
#  2   id_assessment      206 non-null    int64
#  3   assessment_type    206 non-null    object
#  4   date               206 non-null    float64
#  5   weight             206 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 9.8+ KB

# %% [markdown]
# <h2>2---Normalizing or standardizing features.</h2>

# %%
# scale the 'date' column  to a range between 0 and 1. ( normalization)
scaler = MinMaxScaler()
secondtFile_assessments['date'] = scaler.fit_transform(secondtFile_assessments[['date']])

# %%
# scale the 'weight' column  to a range between 0 and 1. 
secondtFile_assessments['weight'] = scaler.fit_transform(secondtFile_assessments[['weight']])

# %%
secondtFile_assessments
# Out:
#     code_module code_presentation  id_assessment assessment_type      date  \
# 0           AAA             2013J           1752             TMA  0.028112
# 1           AAA             2013J           1753             TMA  0.168675
# 2           AAA             2013J           1754             TMA  0.421687
# 3           AAA             2013J           1755             TMA  0.618474
# 4           AAA             2013J           1756             TMA  0.815261
# ..          ...               ...            ...             ...       ...
# 201         GGG             2014J          37443             CMA  0.871486
# 202         GGG             2014J          37435             TMA  0.196787
# 203         GGG             2014J          37436             TMA  0.449799
# 204         GGG             2014J          37437             TMA  0.646586
# 205         GGG             2014J          37444            Exam  0.871486
#
#      weight
# 0       0.1
# 1       0.2
# 2       0.2
# 3       0.2
# ...

# %% [markdown]
# <h2>3--- Encoding categorical variables (if any).</h2>

# %%
secondtFile_assessments = pd.get_dummies(secondtFile_assessments, columns=['code_module', 'code_presentation'])

# %%
label_encoder = LabelEncoder()

# %%
secondtFile_assessments['assessment_type_encoded'] = label_encoder.fit_transform(secondtFile_assessments['assessment_type'])

# %%
secondtFile_assessments.drop(columns=['assessment_type'], inplace=True)

# %%
secondtFile_assessments
# Out:
#      id_assessment      date  weight  code_module_AAA  code_module_BBB  \
# 0             1752  0.028112     0.1             True            False
# 1             1753  0.168675     0.2             True            False
# 2             1754  0.421687     0.2             True            False
# 3             1755  0.618474     0.2             True            False
# 4             1756  0.815261     0.3             True            False
# ..             ...       ...     ...              ...              ...
# 201          37443  0.871486     0.0            False            False
# 202          37435  0.196787     0.0            False            False
# 203          37436  0.449799     0.0            False            False
# 204          37437  0.646586     0.0            False            False
# 205          37444  0.871486     1.0            False            False
#
#      code_module_CCC  code_module_DDD  code_module_EEE  code_module_FFF  \
# ...

# %%
4 + 3 % 5
# Out:
# 7
